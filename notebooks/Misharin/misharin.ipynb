# %% [markdown]
# # Misharin (GSE127803)
# Mice aged 8-10 weeks were instilled intratracheally with control particles or crocidolite asbestos fibers to induce lung fibrosis. Lungs were then harvested at different time points (depending on the analysis method).
#
# Single-cell RNA sequencing was done on a HiSeq 4000 instrument (Illumina) using Chromium Single Cell v2 Reagent Kit and Controller for the library preparation.

# %%
import scanpy
import pandas as pd
import scib
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
import anndata
import helper_classes_DanielStrobl
plt.rcParams['figure.figsize'] = (10, 10)

# %%
base = "GSE127803_RAW"
misharin = scanpy.read(base + '/processed.h5ad')   # read in data
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/X' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/layers' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/layers/counts' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/h5ad.py:280: OldFormatWarning: '/obs' was written with a very old version of AnnData. Consider rewriting it.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/obsm' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/obsm/X_pca' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/obsm/X_umap' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/batch_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/cond_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/is_krt8_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/is_krt8_colors' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain/params' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain/params/random_state' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain/params/resolution' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_colors' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_epi_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_fibro_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_fibro_colors' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/louvain_macro_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/mish_clusters_categories' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/connectivities' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/distances' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/params' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/params/method' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/params/metric' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/params/n_neighbors' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/neighbors/params/use_rep' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/pca' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/pca/variance' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/pca/variance_ratio' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/logfoldchanges' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/names' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params/corr_method' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params/groupby' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params/method' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params/reference' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/params/use_raw' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/pvals' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/pvals_adj' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/rank_genes_groups/scores' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/h5ad.py:280: OldFormatWarning: '/var' was written with a very old version of AnnData. Consider rewriting it.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/varm' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/varm/PCs' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/compat/__init__.py:229: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/utils.py:202: OldFormatWarning: Element '/raw.X' was written without encoding metadata.
#   return func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/anndata/_io/h5ad.py:280: OldFormatWarning: '/raw.var' was written with a very old version of AnnData. Consider rewriting it.
#   warn(

# %% [markdown]
# ## First analyses of the data:

# %%
misharin
# Out:
# AnnData object with n_obs × n_vars = 15365 × 17117
#     obs: 'batch', 'cond', 'n_counts', 'log_counts', 'n_genes', 'percent_mito', 'size_factors', 'louvain', 'mish_clusters', 'louvain_epi', 'louvain_macro', 'louvain_fibro', 'epi_all_score', 'is_krt8'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'is_krt8_colors', 'louvain', 'louvain_colors', 'louvain_fibro_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %%
misharin.obs   # information on cells
# Out:
#                       batch  cond  n_counts  log_counts  n_genes  \
# index
# SC14_AAACCTGAGCGTTCCG     0  SC14    1855.0    7.525640      749
# SC14_AAACCTGAGGACATTA     0  SC14    1479.0    7.299121      629
# SC14_AAACCTGAGTCGTTTG     0  SC14    2638.0    7.877776     1180
# SC14_AAACCTGCACATCCGG     0  SC14    9452.0    9.153981     2498
# SC14_AAACCTGCACTAGTAC     0  SC14    3883.0    8.264363     1139
# ...                     ...   ...       ...         ...      ...
# SC15_TTTGTCAGTGATGTGG     1  SC15    2724.0    7.909857     1141
# SC15_TTTGTCAGTTCGCTAA     1  SC15    2193.0    7.693026      793
# SC15_TTTGTCATCAGTCAGT     1  SC15    4270.0    8.359369     1638
# SC15_TTTGTCATCGCGTAGC     1  SC15    7743.0    8.954544     1803
# SC15_TTTGTCATCGCTGATA     1  SC15    4184.0    8.339023     1341
#
#                        percent_mito  size_factors               louvain  \
# index
# SC14_AAACCTGAGCGTTCCG           0.0      0.380752              t-cells1
# SC14_AAACCTGAGGACATTA           0.0      0.309252              t-cells1
# SC14_AAACCTGAGTCGTTTG           0.0      0.651934  alveolar macrophages
# SC14_AAACCTGCACATCCGG           0.0      2.227473             Monocytes
# SC14_AAACCTGCACTAGTAC           0.0      0.668605               b-cells
# ...                             ...           ...                   ...
# SC15_TTTGTCAGTGATGTGG           0.0      0.655444                     5
# SC15_TTTGTCAGTTCGCTAA           0.0      0.414185               b-cells
# SC15_TTTGTCATCAGTCAGT           0.0      1.126070             Monocytes
# SC15_TTTGTCATCGCGTAGC           0.0      1.483575            dendridic2
# SC15_TTTGTCATCGCTGATA           0.0      0.753837                   AT2
#
#                                             mish_clusters  \
# index
# SC14_AAACCTGAGCGTTCCG                             B cells
# SC14_AAACCTGAGGACATTA                             B cells
# SC14_AAACCTGAGTCGTTTG                Alveolar macrophages
# SC14_AAACCTGCACATCCGG                 Classical monocytes
# SC14_AAACCTGCACTAGTAC                             T cells
# ...                                                   ...
# SC15_TTTGTCAGTGATGTGG             Non-classical monocytes
# SC15_TTTGTCAGTTCGCTAA                             T cells
# SC15_TTTGTCATCAGTCAGT                 Classical monocytes
# SC15_TTTGTCATCGCGTAGC                      Ccr7+Ccl22+ DC
# SC15_TTTGTCATCGCTGATA  AT2 cells (asbestos only, Retnla+)
#
#                                 louvain_epi           louvain_macro  \
# index
# SC14_AAACCTGAGCGTTCCG              t-cells1                t-cells1
# SC14_AAACCTGAGGACATTA              t-cells1                t-cells1
# SC14_AAACCTGAGTCGTTTG  alveolar macrophages  alveolar macrophages,0
# SC14_AAACCTGCACATCCGG             Monocytes               Monocytes
# SC14_AAACCTGCACTAGTAC               b-cells                 b-cells
# ...                                     ...                     ...
# SC15_TTTGTCAGTGATGTGG                     5                       5
# SC15_TTTGTCAGTTCGCTAA               b-cells                 b-cells
# SC15_TTTGTCATCAGTCAGT             Monocytes               Monocytes
# SC15_TTTGTCATCGCGTAGC            dendridic2              dendridic2
# SC15_TTTGTCATCGCTGATA                 AT2,0                     AT2
#
#                                  louvain_fibro  epi_all_score is_krt8
# index
# SC14_AAACCTGAGCGTTCCG                 t-cells1       0.554678      no
# SC14_AAACCTGAGGACATTA                 t-cells1       0.328899      no
# SC14_AAACCTGAGTCGTTTG   alveolar macrophages,0      -0.597836      no
# SC14_AAACCTGCACATCCGG                Monocytes      -3.121701      no
# SC14_AAACCTGCACTAGTAC                  b-cells       0.391317      no
# ...                                        ...            ...     ...
# SC15_TTTGTCAGTGATGTGG  non-classical monocytes      -0.924487      no
# SC15_TTTGTCAGTTCGCTAA                  b-cells       0.306682      no
# SC15_TTTGTCATCAGTCAGT                Monocytes      -1.542132      no
# SC15_TTTGTCATCGCGTAGC               dendridic2       0.648574      no
# SC15_TTTGTCATCGCTGATA                      AT2       0.931578      no
#
# [15365 rows x 14 columns]

# %%
misharin.obs.select_dtypes(include='category')
# Out:
#                       batch  cond               louvain  \
# index
# SC14_AAACCTGAGCGTTCCG     0  SC14              t-cells1
# SC14_AAACCTGAGGACATTA     0  SC14              t-cells1
# SC14_AAACCTGAGTCGTTTG     0  SC14  alveolar macrophages
# SC14_AAACCTGCACATCCGG     0  SC14             Monocytes
# SC14_AAACCTGCACTAGTAC     0  SC14               b-cells
# ...                     ...   ...                   ...
# SC15_TTTGTCAGTGATGTGG     1  SC15                     5
# SC15_TTTGTCAGTTCGCTAA     1  SC15               b-cells
# SC15_TTTGTCATCAGTCAGT     1  SC15             Monocytes
# SC15_TTTGTCATCGCGTAGC     1  SC15            dendridic2
# SC15_TTTGTCATCGCTGATA     1  SC15                   AT2
#
#                                             mish_clusters  \
# index
# SC14_AAACCTGAGCGTTCCG                             B cells
# SC14_AAACCTGAGGACATTA                             B cells
# SC14_AAACCTGAGTCGTTTG                Alveolar macrophages
# SC14_AAACCTGCACATCCGG                 Classical monocytes
# SC14_AAACCTGCACTAGTAC                             T cells
# ...                                                   ...
# SC15_TTTGTCAGTGATGTGG             Non-classical monocytes
# SC15_TTTGTCAGTTCGCTAA                             T cells
# SC15_TTTGTCATCAGTCAGT                 Classical monocytes
# SC15_TTTGTCATCGCGTAGC                      Ccr7+Ccl22+ DC
# SC15_TTTGTCATCGCTGATA  AT2 cells (asbestos only, Retnla+)
#
#                                 louvain_epi           louvain_macro  \
# index
# SC14_AAACCTGAGCGTTCCG              t-cells1                t-cells1
# SC14_AAACCTGAGGACATTA              t-cells1                t-cells1
# SC14_AAACCTGAGTCGTTTG  alveolar macrophages  alveolar macrophages,0
# SC14_AAACCTGCACATCCGG             Monocytes               Monocytes
# SC14_AAACCTGCACTAGTAC               b-cells                 b-cells
# ...                                     ...                     ...
# SC15_TTTGTCAGTGATGTGG                     5                       5
# SC15_TTTGTCAGTTCGCTAA               b-cells                 b-cells
# SC15_TTTGTCATCAGTCAGT             Monocytes               Monocytes
# SC15_TTTGTCATCGCGTAGC            dendridic2              dendridic2
# SC15_TTTGTCATCGCTGATA                 AT2,0                     AT2
#
#                                  louvain_fibro is_krt8
# index
# SC14_AAACCTGAGCGTTCCG                 t-cells1      no
# SC14_AAACCTGAGGACATTA                 t-cells1      no
# SC14_AAACCTGAGTCGTTTG   alveolar macrophages,0      no
# SC14_AAACCTGCACATCCGG                Monocytes      no
# SC14_AAACCTGCACTAGTAC                  b-cells      no
# ...                                        ...     ...
# SC15_TTTGTCAGTGATGTGG  non-classical monocytes      no
# SC15_TTTGTCAGTTCGCTAA                  b-cells      no
# SC15_TTTGTCATCAGTCAGT                Monocytes      no
# SC15_TTTGTCATCGCGTAGC               dendridic2      no
# SC15_TTTGTCATCGCTGATA                      AT2      no
#
# [15365 rows x 8 columns]

# %% [markdown]
# ## Filtering outliers:
# Previously done:
# - sc.pp.filter_cells(misharin, max_counts=30000)
# - sc.pp.filter_cells(misharin, max_genes=5200)
# - sc.pp.filter_cells(misharin, min_genes=400)

# %%
scib.pp.summarize_counts(misharin)
scib.pp.plot_qc(misharin)

# %%
plt.hist(misharin.obs["n_counts"], bins=100, edgecolor='black')   # distribution of n_counts
plt.xlabel('n_counts')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
scanpy.pp.filter_cells(misharin, max_counts=30000)
scanpy.pp.filter_cells(misharin, max_genes=5200)
scanpy.pp.filter_cells(misharin, min_genes=400)

# %%
plt.hist(misharin.obs["n_counts"], bins=100, edgecolor='black')   # distribution of n_counts
plt.xlabel('n_counts')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ## UMAPs:
# SC14 = 0 = Control
# SC15 = 1 = Fibrosis

# %%
misharin.obs['cond']='control'
misharin.obs.loc[misharin.obs.batch=='1', 'cond']='fibrosis'

# %%
scanpy.pl.umap(misharin, color=['cond'], size=30)   # condition = batch
scanpy.pl.umap(misharin, color=['mish_clusters'], size=30)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
scanpy.pp.pca(misharin)
scanpy.pl.pca_scatter(misharin, color="n_counts")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:163: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))

# %%
(misharin.obs['cond']=='control').sum()
# Out:
# 8248

# %%
(misharin.obs['cond']=='fibrosis').sum()
# Out:
# 7117

# %%
(misharin.obs['cond']=='control').sum() + (misharin.obs['cond']=='fibrosis').sum()
# Out:
# 15365

# %% [markdown]
# # Differential gene expression analysis - code example for pseudobulk
# Using the data set Misharin.

# %% [markdown]
# ## 1. Environment setup

# %%
import warnings

warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import pandas as pd
import numpy as np
import random
import sc_toolbox
import anndata

import rpy2.rinterface_lib.callbacks
import anndata2ri
import logging

from rpy2.robjects import pandas2ri
from rpy2.robjects import r
import rpy2.robjects.numpy2ri

sc.settings.verbosity = 0
rpy2.rinterface_lib.callbacks.logger.setLevel(logging.ERROR)

pandas2ri.activate()
anndata2ri.activate()
rpy2.robjects.numpy2ri.activate()

# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(edgeR)

# %% [markdown]
# ## 2. Preparing the dataset

# %%
adata = sc.read("/home/sch/schonner/MaPra/misharin_Emma_for_merging.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 15365 × 27998
#     obs: 'batch', 'author_annotation', 'manual_celltype_annotation', 'condition'

# %% [markdown]
# ### We will need label (which contains the condition label), replicate and cell_type columns of the .obs
#
# ---> condition, batch and manual_celltype_annotation in this data set

# %%
adata.obs[:5]
# Out:
#                        batch     author_annotation manual_celltype_annotation  \
# SC14_AAACCTGAGCGTTCCG      0               B cells                    B-cells
# SC14_AAACCTGAGGACATTA      0               B cells                    B-cells
# SC14_AAACCTGAGTCGTTTG      0  Alveolar macrophages       Alveolar macrophages
# SC14_AAACCTGCACATCCGG      0   Classical monocytes        Classical monocytes
# SC14_AAACCTGCACTAGTAC      0               T cells                    T-cells
#
#                       condition
# SC14_AAACCTGAGCGTTCCG   control
# SC14_AAACCTGAGGACATTA   control
# SC14_AAACCTGAGTCGTTTG   control
# SC14_AAACCTGCACATCCGG   control
# SC14_AAACCTGCACTAGTAC   control

# %% [markdown]
# ### We will need to work with raw counts so we check that .X indeed contains raw counts and put them into the counts layer of our AnnData object.

# %%
np.max(adata.X)
# Out:
# 19899.0

# %%
adata.layers["counts"] = adata.X.copy()

# %% [markdown]
# ### Rudimentary quality control (taken from the book chapter):

# %%
sc.pp.filter_cells(adata, min_genes=200)   # filter cells which have less than 200 genes
sc.pp.filter_genes(adata, min_cells=3)     # filter genes which were found in less than 3 cells
adata
# Out:
# AnnData object with n_obs × n_vars = 15365 × 17832
#     obs: 'batch', 'author_annotation', 'manual_celltype_annotation', 'condition', 'n_genes'
#     var: 'n_cells'
#     layers: 'counts'

# %% [markdown]
# ## 3. Pseudobulk
# -> may not work for this data set as it only has two samples (but important for other data sets)

# %%
# create patient-condition combinations -> not really possible for this data set
adata.obs["sample"] = [
    f"{rep}_{l}" for rep, l in zip(adata.obs["batch"], adata.obs["condition"])
]

# %%
# clean up the cell type names
adata.obs["manual_celltype_annotation"] = [ct.replace(" ", "_") for ct in adata.obs["manual_celltype_annotation"]]
adata.obs["manual_celltype_annotation"] = [ct.replace("+", "") for ct in adata.obs["manual_celltype_annotation"]]
adata.obs["manual_celltype_annotation"] = [ct.replace(".", "_") for ct in adata.obs["manual_celltype_annotation"]]

# %%
# set categorical metadata to be indeed categorical to create pseudobulks 
adata.obs["batch"] = adata.obs["batch"].astype("category")
adata.obs["condition"] = adata.obs["condition"].astype("category")
adata.obs["sample"] = adata.obs["sample"].astype("category")
adata.obs["manual_celltype_annotation"] = adata.obs["manual_celltype_annotation"].astype("category")

# %% [markdown]
# ### Define the function we need to aggregate single cells into pseudo-replicates:

# %%
NUM_OF_CELL_PER_DONOR = 30   # TODO: can this number be used?


def aggregate_and_filter(
    adata,
    cell_identity,
    donor_key="sample",
    condition_key="batch",
    cell_identity_key="manual_celltype_annotation",
    obs_to_keep=[],  # which additional metadata to keep, e.g. gender, age, etc.
    replicates_per_patient=1,
):
    # subset adata to the given cell identity
    adata_cell_pop = adata[adata.obs[cell_identity_key] == cell_identity].copy()
    # check which donors to keep according to the number of cells specified with NUM_OF_CELL_PER_DONOR
    size_by_donor = adata_cell_pop.obs.groupby([donor_key]).size()
    donors_to_drop = [
        donor
        for donor in size_by_donor.index
        if size_by_donor[donor] <= NUM_OF_CELL_PER_DONOR
    ]
    if len(donors_to_drop) > 0:
        print("Dropping the following samples:")
        print(donors_to_drop)
    df = pd.DataFrame(columns=[*adata_cell_pop.var_names, *obs_to_keep])

    adata_cell_pop.obs[donor_key] = adata_cell_pop.obs[donor_key].astype("category")
    for i, donor in enumerate(donors := adata_cell_pop.obs[donor_key].cat.categories):
        print(f"\tProcessing donor {i+1} out of {len(donors)}...", end="\r")
        if donor not in donors_to_drop:
            adata_donor = adata_cell_pop[adata_cell_pop.obs[donor_key] == donor]
            # create replicates for each donor
            indices = list(adata_donor.obs_names)
            random.shuffle(indices)
            indices = np.array_split(np.array(indices), replicates_per_patient)
            for i, rep_idx in enumerate(indices):
                adata_replicate = adata_donor[rep_idx]
                # specify how to aggregate: sum gene expression for each gene for each donor and also keep the condition information
                agg_dict = {gene: "sum" for gene in adata_replicate.var_names}
                for obs in obs_to_keep:
                    agg_dict[obs] = "first"
                # create a df with all genes, donor and condition info
                df_donor = pd.DataFrame(adata_replicate.X.A)
                df_donor.index = adata_replicate.obs_names
                df_donor.columns = adata_replicate.var_names
                df_donor = df_donor.join(adata_replicate.obs[obs_to_keep])
                # aggregate
                df_donor = df_donor.groupby(donor_key).agg(agg_dict)
                df_donor[donor_key] = donor
                df.loc[f"donor_{donor}_{i}"] = df_donor.loc[donor]
    print("\n")
    # create AnnData object from the df
    adata_cell_pop = sc.AnnData(
        df[adata_cell_pop.var_names], obs=df.drop(columns=adata_cell_pop.var_names)
    )
    return adata_cell_pop

# %% [markdown]
# ### Separate function to fit an edgeR GLM:

# %%
# %%R
# fit_model <- function(adata_){
#     # create an edgeR object with counts and grouping factor
#     y <- DGEList(assay(adata_, "X"), group = colData(adata_)$label)
#     # filter out genes with low counts
#     print("Dimensions before subsetting:")
#     print(dim(y))
#     print("")
#     keep <- filterByExpr(y)
#     y <- y[keep, , keep.lib.sizes=FALSE]
#     print("Dimensions after subsetting:")
#     print(dim(y))
#     print("")
#     # normalize
#     y <- calcNormFactors(y)
#     # create a vector that is concatentation of condition and cell type that we will later use with contrasts
#     group <- paste0(colData(adata_)$label, ".", colData(adata_)$cell_type)
#     replicate <- colData(adata_)$replicate
#     # create a design matrix: here we have multiple donors so also consider that in the design matrix
#     design <- model.matrix(~ 0 + group + replicate)
#     # estimate dispersion
#     y <- estimateDisp(y, design = design)
#     # fit the model
#     fit <- glmQLFit(y, design)
#     return(list("fit"=fit, "design"=design, "y"=y))
# }

# %% [markdown]
# ### Create the AnnData object with pseudobulks:

# %%
obs_to_keep = ["condition", "manual_celltype_annotation", "batch", "sample"]

# %%
adata.X = adata.layers["counts"].copy()

# %%
adata.obs["manual_celltype_annotation"].cat.categories
# Out:
# Index(['AT1', 'AT2', 'Aerocyte', 'Alveolar_fibroblast', 'Alveolar_macrophages',
#        'B-cells', 'Classical_monocytes', 'Dendritic_cells',
#        'Dendritic_cells_Ccr7-hi', 'Endothelial', 'Interstitial_macrophages',
#        'Myofibroblasts', 'NK_cells', 'Neutrophils', 'Non-classical_monocytes',
#        'T-cells', 'Transitioning_epithelial'],
#       dtype='object')

# %%
# process first cell type separately...
cell_type = adata.obs["manual_celltype_annotation"].cat.categories[0]
print(
    f'Processing {cell_type} (1 out of {len(adata.obs["manual_celltype_annotation"].cat.categories)})...'
)
adata_pb = aggregate_and_filter(adata, cell_type, obs_to_keep=obs_to_keep)
for i, cell_type in enumerate(adata.obs["manual_celltype_annotation"].cat.categories[1:]):
    print(
        f'Processing {cell_type} ({i+2} out of {len(adata.obs["manual_celltype_annotation"].cat.categories)})...'
    )
    adata_cell_type = aggregate_and_filter(adata, cell_type, obs_to_keep=obs_to_keep)
    adata_pb = anndata.concat([adata_pb, adata_cell_type])   # --> adata_pb.concatenate(adata_cell_type) does not work!
# Out:
# Processing AT1 (1 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing AT2 (2 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Aerocyte (3 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Alveolar_fibroblast (4 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Alveolar_macrophages (5 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing B-cells (6 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Classical_monocytes (7 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Dendritic_cells (8 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Dendritic_cells_Ccr7-hi (9 out of 17)...
# Dropping the following samples:
# ['0_control']
# 	Processing donor 2 out of 2...
#
# Processing Endothelial (10 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Interstitial_macrophages (11 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Myofibroblasts (12 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing NK_cells (13 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Neutrophils (14 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Non-classical_monocytes (15 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing T-cells (16 out of 17)...
# 	Processing donor 2 out of 2...
#
# Processing Transitioning_epithelial (17 out of 17)...
# 	Processing donor 2 out of 2...

# %% [markdown]
# ### Saving data and first visualizations:

# %%
adata_pb.layers['counts'] = adata_pb.X.copy()

# %%
sc.pp.normalize_total(adata_pb, target_sum=1e6)
sc.pp.log1p(adata_pb)
sc.pp.pca(adata_pb)

# %%
adata_pb.obs["lib_size"] = np.sum(adata_pb.layers["counts"], axis=1)
adata_pb.obs["lib_size"] = adata_pb.obs["lib_size"].astype(float)   # --> not in example but important
adata_pb.obs["log_lib_size"] = np.log(adata_pb.obs["lib_size"])

# %%
sc.pl.pca(adata_pb, color=adata_pb.obs, ncols=1, size=300)

# %%
adata_pb.X = adata_pb.layers['counts'].copy()

# %% [markdown]
# ### 3.1. One group

# %%
adata_AT1 = adata_pb[adata_pb.obs["manual_celltype_annotation"] == "AT1"]
adata_AT1
# Out:
# View of AnnData object with n_obs × n_vars = 2 × 17832
#     obs: 'condition', 'manual_celltype_annotation', 'batch', 'sample', 'lib_size', 'log_lib_size'
#     uns: 'log1p', 'pca', 'condition_colors', 'manual_celltype_annotation_colors', 'sample_colors'
#     obsm: 'X_pca'
#     varm: 'PCs'
#     layers: 'counts'

# %%
adata_AT1.obs_names = [
    name.split("_")[2] + "_" + name.split("_")[3] for name in adata_AT1.obs_names
]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 adata_AT1.obs_names = [
#       2     name.split("_")[2] + "_" + name.split("_")[3] for name in adata_AT1.obs_names
#       3 ]
#
# Cell In[31], line 2, in <listcomp>(.0)
#       1 adata_AT1.obs_names = [
# ----> 2     name.split("_")[2] + "_" + name.split("_")[3] for name in adata_AT1.obs_names
#       3 ]
#
# IndexError: list index out of range

# %%
# %%time
# %%R -i adata_AT1
outs <- fit_model(adata_AT1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:896, in RMagics.R(self, line, cell, local_ns)
#     894     with localconverter(converter) as cv:
#     895         for arg in ','.join(args.input).split(','):
# --> 896             self._import_name_into_r(arg, ro.globalenv, local_ns)
#     898 if args.display:
#     899     try:
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:424, in RMagics._import_name_into_r(self, arg, env, local_ns)
#     422         val = _find(rhs, self.shell.user_ns)
#     423 if val is not None:
# --> 424     env[lhs] = val
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/environments.py:35, in Environment.__setitem__(self, item, value)
#      34 def __setitem__(self, item: str, value: typing.Any) -> None:
# ---> 35     robj = conversion.get_conversion().py2rpy(value)
#      36     super(Environment, self).__setitem__(item, robj)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/anndata2ri/py2r.py:55, in py2rpy_anndata(obj)
#      53 sce = importr('SingleCellExperiment')
#      54 # TODO: sparse
# ---> 55 x = {} if obj.X is None else dict(X=mat_converter.py2rpy(obj.X.T))
#      56 layers = {k: mat_converter.py2rpy(v.T) for k, v in obj.layers.items()}
#      57 assays = ListVector({**x, **layers})
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/numpy2ri.py:102, in numpy2rpy(o)
#     100 # Array-of-PyObject is treated like a Python list:
#     101 elif o.dtype.kind == 'O':
# --> 102     res = numpy_O_py2rpy(o)
#     103 # Record arrays map onto R data frames:
#     104 elif o.dtype.kind == 'V':
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/numpy2ri.py:57, in numpy_O_py2rpy(o)
#      55     res = ByteSexpVector(o)
#      56 else:
# ---> 57     res = conversion.get_conversion().py2rpy(list(o))
#      58 return res
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/__init__.py:308, in _py2rpy_list(obj)
#     303 @default_converter.py2rpy.register(list)
#     304 def _py2rpy_list(obj):
#     305     cv = conversion.get_conversion()
#     306     return vectors.ListVector(
#     307         rinterface.ListSexpVector(
# --> 308             [cv.py2rpy(x) for x in obj]
#     309         )
#     310     )
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/__init__.py:308, in <listcomp>(.0)
#     303 @default_converter.py2rpy.register(list)
#     304 def _py2rpy_list(obj):
#     305     cv = conversion.get_conversion()
#     306     return vectors.ListVector(
#     307         rinterface.ListSexpVector(
# --> 308             [cv.py2rpy(x) for x in obj]
#     309         )
#     310     )
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/conversion.py:240, in _py2rpy(obj)
#     238 if isinstance(obj, _rinterface_capi.SupportsSEXP):
#     239     return obj
# --> 240 raise NotImplementedError(
#     241     "Conversion 'py2rpy' not defined for objects of type '%s'" %
#     242     str(type(obj))
#     243 )
#
# NotImplementedError: Conversion 'py2rpy' not defined for objects of type '<class 'numpy.ndarray'>'

# %%
# %%R
# fit <- outs$fit
# y <- outs$y

# %%
# %%R
# plotMDS(y, col=ifelse(y$samples$group == "stim", "red", "blue"))

# %%
# %%R
# plotBCV(y)
# Out:
# Error in is(y, "DGEList") : object 'y' not found
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:385, in RMagics.eval(self, code)
#     383 try:
#     384     # Need the newline in case the last line in code is a comment.
# --> 385     value, visible = ro.r("withVisible({%s\n})" % code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/__init__.py:459, in R.__call__(self, string)
#     458 p = rinterface.parse(string)
# --> 459 res = self.eval(p)
#     460 return conversion.get_conversion().rpy2py(res)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/functions.py:208, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     207         kwargs[r_k] = v
# --> 208 return (super(SignatureTranslatedFunction, self)
#     209         .__call__(*args, **kwargs))
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/functions.py:131, in Function.__call__(self, *args, **kwargs)
#     130         new_kwargs[k] = cv.py2rpy(v)
# --> 131 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     132 res = cv.rpy2py(res)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/rinterface.py:817, in SexpClosure.__call__(self, *args, **kwargs)
#     816     if error_occured[0]:
# --> 817         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     818 return res
#
# RRuntimeError: Error in is(y, "DGEList") : object 'y' not found
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 get_ipython().run_cell_magic('R', '', 'plotBCV(y)\n')
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:943, in RMagics.R(self, line, cell, local_ns)
#     941     if not e.stdout.endswith(e.err):
#     942         print(e.err)
# --> 943     raise e
#     944 finally:
#     945     if self.device in DEVICES_STATIC:
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:923, in RMagics.R(self, line, cell, local_ns)
#     921         return_output = False
#     922 else:
# --> 923     text_result, result, visible = self.eval(code)
#     924     text_output += text_result
#     925     if visible:
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:389, in RMagics.eval(self, code)
#     386 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     387     # Otherwise next return seems to have copy of error.
#     388     warning_or_other_msg = self.flush()
# --> 389     raise RInterpreterError(code, str(exception),
#     390                             warning_or_other_msg)
#     391 text_output = self.flush()
#     392 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line 'plotBCV(y)\n'.
# R error message: 'Error in is(y, "DGEList") : object \'y\' not found'

# %%
# %%R -o tt
# myContrast <- makeContrasts('groupstim.AT1-groupctrl.AT1', levels = y$design)
# qlf <- glmQLFTest(fit, contrast=myContrast)
# # get all of the DE genes and calculate Benjamini-Hochberg adjusted FDR
# tt <- topTags(qlf, n = Inf)
# tt <- tt$table

# %%
# %%R
# tr <- glmTreat(fit, contrast=myContrast, lfc=1.5)
# print(head(topTags(tr)))

# %%
# %%R
# plotSmear(qlf, de.tags = rownames(tt)[which(tt$FDR<0.01)])

# %% [markdown]
# ### 3.2. Multiple groups

# %%
# %%time
# %%R -i adata_pb
outs <-fit_model(adata_pb)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:896, in RMagics.R(self, line, cell, local_ns)
#     894     with localconverter(converter) as cv:
#     895         for arg in ','.join(args.input).split(','):
# --> 896             self._import_name_into_r(arg, ro.globalenv, local_ns)
#     898 if args.display:
#     899     try:
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/ipython/rmagic.py:424, in RMagics._import_name_into_r(self, arg, env, local_ns)
#     422         val = _find(rhs, self.shell.user_ns)
#     423 if val is not None:
# --> 424     env[lhs] = val
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/environments.py:35, in Environment.__setitem__(self, item, value)
#      34 def __setitem__(self, item: str, value: typing.Any) -> None:
# ---> 35     robj = conversion.get_conversion().py2rpy(value)
#      36     super(Environment, self).__setitem__(item, robj)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/anndata2ri/py2r.py:55, in py2rpy_anndata(obj)
#      53 sce = importr('SingleCellExperiment')
#      54 # TODO: sparse
# ---> 55 x = {} if obj.X is None else dict(X=mat_converter.py2rpy(obj.X.T))
#      56 layers = {k: mat_converter.py2rpy(v.T) for k, v in obj.layers.items()}
#      57 assays = ListVector({**x, **layers})
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/numpy2ri.py:102, in numpy2rpy(o)
#     100 # Array-of-PyObject is treated like a Python list:
#     101 elif o.dtype.kind == 'O':
# --> 102     res = numpy_O_py2rpy(o)
#     103 # Record arrays map onto R data frames:
#     104 elif o.dtype.kind == 'V':
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/numpy2ri.py:57, in numpy_O_py2rpy(o)
#      55     res = ByteSexpVector(o)
#      56 else:
# ---> 57     res = conversion.get_conversion().py2rpy(list(o))
#      58 return res
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/__init__.py:308, in _py2rpy_list(obj)
#     303 @default_converter.py2rpy.register(list)
#     304 def _py2rpy_list(obj):
#     305     cv = conversion.get_conversion()
#     306     return vectors.ListVector(
#     307         rinterface.ListSexpVector(
# --> 308             [cv.py2rpy(x) for x in obj]
#     309         )
#     310     )
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/__init__.py:308, in <listcomp>(.0)
#     303 @default_converter.py2rpy.register(list)
#     304 def _py2rpy_list(obj):
#     305     cv = conversion.get_conversion()
#     306     return vectors.ListVector(
#     307         rinterface.ListSexpVector(
# --> 308             [cv.py2rpy(x) for x in obj]
#     309         )
#     310     )
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/rpy2/robjects/conversion.py:240, in _py2rpy(obj)
#     238 if isinstance(obj, _rinterface_capi.SupportsSEXP):
#     239     return obj
# --> 240 raise NotImplementedError(
#     241     "Conversion 'py2rpy' not defined for objects of type '%s'" %
#     242     str(type(obj))
#     243 )
#
# NotImplementedError: Conversion 'py2rpy' not defined for objects of type '<class 'numpy.ndarray'>'

# %%
# %%R
# fit <- outs$fit
# y <- outs$y

# %%
# %%R -i adata_pb -o de_per_cell_type
# de_per_cell_type <- list()
# for (cell_type in unique(colData(adata_pb)$cell_type)) {
#     print(cell_type)
#     # create contrast for this cell type
#     myContrast <- makeContrasts(paste0("groupstim.", cell_type, "-groupctrl.", cell_type), levels = y$design)
#     # perform QLF test
#     qlf <- glmQLFTest(fit, contrast=myContrast)
#     # get all of the DE genes and calculate Benjamini-Hochberg adjusted FDR
#     tt <- topTags(qlf, n = Inf)
#     # save in the list with the results for all the cell types
#     de_per_cell_type[[cell_type]] <- tt$table
# }

# %%
# get cell types that we ran the analysis for
cell_types = de_per_cell_type.keys()
# add the table to .uns for each cell type
for cell_type in cell_types:
    df = de_per_cell_type[cell_type]
    df["gene_symbol"] = df.index
    df["cell_type"] = cell_type
    sc_toolbox.tools.de_res_to_anndata(
        adata,
        df,
        groupby="cell_type",
        score_col="logCPM",
        pval_col="PValue",
        pval_adj_col="FDR",
        lfc_col="logFC",
        key_added="edgeR_" + cell_type,
    )
    df.to_csv(f"de_edgeR_{cell_type}.csv")

# %%
sc.get.rank_genes_groups_df(adata, group="CD14_Monocytes", key="edgeR_CD14_Monocytes")[
    :5
]

# %% [markdown]
# ## 4. Visualization

# %%
adata.X = adata.layers["counts"].copy()
sc.pp.normalize_total(adata, target_sum=1e6)
sc.pp.log1p(adata)

# %% [markdown]
# ### Define a helper definition for heat maps:

# %%
FDR = 0.01
LOG_FOLD_CHANGE = 1.5


def plot_heatmap(adata, group_key, group_name="cell_type", groupby="label"):
    cell_type = "_".join(group_key.split("_")[1:])
    res = sc.get.rank_genes_groups_df(adata, group=cell_type, key=group_key)
    res.index = res["names"].values
    res = res[
        (res["pvals_adj"] < FDR) & (abs(res["logfoldchanges"]) > LOG_FOLD_CHANGE)
    ].sort_values(by=["logfoldchanges"])
    print(f"Plotting {len(res)} genes...")
    markers = list(res.index)
    sc.pl.heatmap(
        adata[adata.obs[group_name] == cell_type].copy(),
        markers,
        groupby=groupby,
        swap_axes=True,
    )

# %%
plot_heatmap(adata, "edgeR_AT1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 plot_heatmap(adata, "edgeR_AT1")
#
# Cell In[61], line 7, in plot_heatmap(adata, group_key, group_name, groupby)
#       5 def plot_heatmap(adata, group_key, group_name="cell_type", groupby="label"):
#       6     cell_type = "_".join(group_key.split("_")[1:])
# ----> 7     res = sc.get.rank_genes_groups_df(adata, group=cell_type, key=group_key)
#       8     res.index = res["names"].values
#       9     res = res[
#      10         (res["pvals_adj"] < FDR) & (abs(res["logfoldchanges"]) > LOG_FOLD_CHANGE)
#      11     ].sort_values(by=["logfoldchanges"])
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/scanpy/get/get.py:64, in rank_genes_groups_df(adata, group, key, pval_cutoff, log2fc_min, log2fc_max, gene_symbols)
#      61     group = list(adata.uns[key]['names'].dtype.names)
#      62 colnames = ['names', 'scores', 'logfoldchanges', 'pvals', 'pvals_adj']
# ---> 64 d = [pd.DataFrame(adata.uns[key][c])[group] for c in colnames]
#      65 d = pd.concat(d, axis=1, names=[None, 'group'], keys=colnames)
#      66 d = d.stack(level=1).reset_index()
#
# File ~/mambaforge/envs/scanpy_diffEx/lib/python3.9/site-packages/scanpy/get/get.py:64, in <listcomp>(.0)
#      61     group = list(adata.uns[key]['names'].dtype.names)
#      62 colnames = ['names', 'scores', 'logfoldchanges', 'pvals', 'pvals_adj']
# ---> 64 d = [pd.DataFrame(adata.uns[key][c])[group] for c in colnames]
#      65 d = pd.concat(d, axis=1, names=[None, 'group'], keys=colnames)
#      66 d = d.stack(level=1).reset_index()
#
# KeyError: 'edgeR_AT1'

# %% [markdown]
# ### Define a helper definition for vulcano plots:

# %%
FDR = 0.01
LOG_FOLD_CHANGE = 1.5


def volcano_plot(adata, group_key, group_name="cell_type", groupby="label", title=None):
    cell_type = "_".join(group_key.split("_")[1:])
    result = sc.get.rank_genes_groups_df(adata, group=cell_type, key=group_key).copy()
    result["-logQ"] = -np.log(result["pvals"].astype("float"))
    lowqval_de = result.loc[abs(result["logfoldchanges"]) > LOG_FOLD_CHANGE]
    other_de = result.loc[abs(result["logfoldchanges"]) <= LOG_FOLD_CHANGE]

    fig, ax = plt.subplots()
    sns.regplot(
        x=other_de["logfoldchanges"],
        y=other_de["-logQ"],
        fit_reg=False,
        scatter_kws={"s": 6},
    )
    sns.regplot(
        x=lowqval_de["logfoldchanges"],
        y=lowqval_de["-logQ"],
        fit_reg=False,
        scatter_kws={"s": 6},
    )
    ax.set_xlabel("log2 FC")
    ax.set_ylabel("-log Q-value")

    if title is None:
        title = group_key.replace("_", " ")
    plt.title(title)
    plt.show()

# %%
volcano_plot(adata, "edgeR_AT1")

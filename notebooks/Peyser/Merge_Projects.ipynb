# %% [markdown]
# # Merge Projects Peyser and Misharin

# %%
import scanpy as sc
import os
import gzip
import shutil
from tqdm.notebook import tqdm
import anndata
import matplotlib.pyplot as plt
import helpers_danielstrobel
from IPython.display import Image
import numpy as np
import seaborn as sns
from scipy.stats import median_abs_deviation
import anndata2ri
import logging
import scrublet
import pandas as pd

import rpy2.rinterface_lib.callbacks as rcb
import rpy2.robjects as ro

rcb.logger.setLevel(logging.ERROR)
ro.pandas2ri.activate()
anndata2ri.activate()

# %load_ext rpy2.ipython

sc.settings.verbosity = 0
sc.settings.set_figure_params(
    dpi=80,
    facecolor="white",
    frameon=False,
)
plt.rcParams['figure.figsize'] = (9, 9)
# Out:
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/rpy2/robjects/pandas2ri.py:368: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   warnings.warn('The global conversion available with activate() '
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/rpy2/robjects/numpy2ri.py:241: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   warnings.warn('The global conversion available with activate() '
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/rpy2/robjects/conversion.py:28: DeprecationWarning: The use of converter in module rpy2.robjects.conversion is deprecated. Use rpy2.robjects.conversion.get_conversion() instead of rpy2.robjects.conversion.converter.
#   warnings.warn(
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/scanpy/_settings.py:447: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   IPython.display.set_matplotlib_formats(*ipython_format)

# %%
adata_peyser = sc.read("data/adata_annotated_lea.h5ad")
adata_misharin = sc.read("data/misharin_Emma_processed_annotated.h5ad")
# Out:
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/dea_louvain_0_5_filtered' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/anndata/_io/specs/registry.py:235: OldFormatWarning: Element '/uns/dea_louvain_0_5_filtered/names' was written without encoding metadata.
#   return self.callback(read_func, elem.name, elem, iospec=get_spec(elem))

# %%
adata_peyser.obs
# Out:
#                                          samples         GSM   condition
# AAACCTGAGGAATTAC-1      GSM3716976_saline.947170  GSM3716976      saline  \
# AAACCTGCATAACCTG-1      GSM3716976_saline.947170  GSM3716976      saline
# AAACCTGCATTGGGCC-1      GSM3716976_saline.947170  GSM3716976      saline
# AAACCTGGTCTCAACA-1      GSM3716976_saline.947170  GSM3716976      saline
# AAACCTGGTTGACGTT-1      GSM3716976_saline.947170  GSM3716976      saline
# ...                                          ...         ...         ...
# TTTGCGCCAGACAAGC-1  GSM3716985_nintedanib.947178  GSM3716985  nintedanib
# TTTGCGCGTCATATGC-1  GSM3716985_nintedanib.947178  GSM3716985  nintedanib
# TTTGCGCGTCCGAATT-1  GSM3716985_nintedanib.947178  GSM3716985  nintedanib
# TTTGGTTGTAGCTTGT-1  GSM3716985_nintedanib.947178  GSM3716985  nintedanib
# TTTGGTTTCATCGATG-1  GSM3716985_nintedanib.947178  GSM3716985  nintedanib
#
#                         id  n_genes_by_counts  log1p_n_genes_by_counts
# AAACCTGAGGAATTAC-1  947170               1158                 7.055313  \
# AAACCTGCATAACCTG-1  947170               1526                 7.331060
# AAACCTGCATTGGGCC-1  947170               2115                 7.657283
# AAACCTGGTCTCAACA-1  947170               2395                 7.781556
# AAACCTGGTTGACGTT-1  947170               1154                 7.051856
# ...                    ...                ...                      ...
# TTTGCGCCAGACAAGC-1  947178               2766                 7.925519
# TTTGCGCGTCATATGC-1  947178               1273                 7.149917
# TTTGCGCGTCCGAATT-1  947178               1472                 7.295056
# TTTGGTTGTAGCTTGT-1  947178               1673                 7.422971
# TTTGGTTTCATCGATG-1  947178               1381                 7.231287
#
#                     total_counts  log1p_total_counts
# AAACCTGAGGAATTAC-1        2729.0            7.912057  \
# AAACCTGCATAACCTG-1        6030.0            8.704668
# AAACCTGCATTGGGCC-1        5689.0            8.646465
# AAACCTGGTCTCAACA-1        8031.0            8.991189
# AAACCTGGTTGACGTT-1        2060.0            7.630947
# ...                          ...                 ...
# TTTGCGCCAGACAAGC-1       13438.0            9.505917
# TTTGCGCGTCATATGC-1        3268.0            8.092239
# TTTGCGCGTCCGAATT-1        4342.0            8.376321
# TTTGGTTGTAGCTTGT-1        5851.0            8.674539
# TTTGGTTTCATCGATG-1        3371.0            8.123261
#
#                     pct_counts_in_top_20_genes  total_counts_mt  ...  outlier
# AAACCTGAGGAATTAC-1                   22.792232              0.0  ...    False  \
# AAACCTGCATAACCTG-1                   23.598673              0.0  ...    False
# AAACCTGCATTGGGCC-1                   19.968360              0.0  ...    False
# AAACCTGGTCTCAACA-1                   28.066243              0.0  ...    False
# AAACCTGGTTGACGTT-1                   18.203883              0.0  ...    False
# ...                                        ...              ...  ...      ...
# TTTGCGCCAGACAAGC-1                   35.280548              0.0  ...    False
# TTTGCGCGTCATATGC-1                   30.293758              0.0  ...    False
# TTTGCGCGTCCGAATT-1                   19.345924              0.0  ...    False
# TTTGGTTGTAGCTTGT-1                   20.133311              0.0  ...    False
# TTTGGTTTCATCGATG-1                   18.540492              0.0  ...    False
#
#                     mt_outlier  n_genes     n_counts  doublet_score
# AAACCTGAGGAATTAC-1       False     1158  1657.952515       0.007582  \
# AAACCTGCATAACCTG-1       False     1526  1552.569580       0.010634
# AAACCTGCATTGGGCC-1       False     2115  2086.439697       0.003242
# AAACCTGGTCTCAACA-1       False     2395  2038.384766       0.004266
# AAACCTGGTTGACGTT-1       False     1154  1799.102539       0.005743
# ...                        ...      ...          ...            ...
# TTTGCGCCAGACAAGC-1       False     2766  1828.999146       0.012512
# TTTGCGCGTCATATGC-1       False     1273  1670.374634       0.010634
# TTTGCGCGTCCGAATT-1       False     1472  1757.693481       0.003576
# TTTGGTTGTAGCTTGT-1       False     1673  1703.329590       0.007368
# TTTGGTTTCATCGATG-1       False     1381  1772.356567       0.019080
#
#                     predicted_doublet  is_doublet  louvain  annotation_coarse
# AAACCTGAGGAATTAC-1              False       False        0        Macrophages  \
# AAACCTGCATAACCTG-1              False       False        5            B-Cells
# AAACCTGCATTGGGCC-1              False       False        8        Mesothelial
# AAACCTGGTCTCAACA-1              False       False        4      Macrophages 2
# AAACCTGGTTGACGTT-1              False       False        1        Endothelial
# ...                               ...         ...      ...                ...
# TTTGCGCCAGACAAGC-1              False       False        4      Macrophages 2
# TTTGCGCGTCATATGC-1              False       False        4      Macrophages 2
# TTTGCGCGTCCGAATT-1              False       False       10        Monocytes 2
# TTTGGTTGTAGCTTGT-1              False       False        5            B-Cells
# TTTGGTTTCATCGATG-1              False       False        2            T-Cells
#
#                        annotation_coarse_precise
# AAACCTGAGGAATTAC-1   Interstitial \n Macrophages
# AAACCTGCATAACCTG-1                       B-Cells
# AAACCTGCATTGGGCC-1                   Mesothelial
# AAACCTGGTCTCAACA-1         Avolare \nMacrophages
# AAACCTGGTTGACGTT-1                   Endothelial
# ...                                          ...
# TTTGCGCCAGACAAGC-1         Avolare \nMacrophages
# TTTGCGCGTCATATGC-1         Avolare \nMacrophages
# TTTGCGCGTCCGAATT-1                   Monocytes 2
# TTTGGTTGTAGCTTGT-1                       B-Cells
# TTTGGTTTCATCGATG-1  T-Cells \n (CD3-Lymphozyten)
#
# [17544 rows x 28 columns]

# %%
adata_misharin.obs
# Out:
#                        batch      cond  n_genes_by_counts
# SC14_AAACCTGAGCGTTCCG      0   control                749  \
# SC14_AAACCTGAGGACATTA      0   control                629
# SC14_AAACCTGAGTCGTTTG      0   control               1180
# SC14_AAACCTGCACATCCGG      0   control               2498
# SC14_AAACCTGCACTAGTAC      0   control               1139
# ...                      ...       ...                ...
# SC15_TTTGTCAGTGATGTGG      1  fibrosis               1141
# SC15_TTTGTCAGTTCGCTAA      1  fibrosis                793
# SC15_TTTGTCATCAGTCAGT      1  fibrosis               1638
# SC15_TTTGTCATCGCGTAGC      1  fibrosis               1803
# SC15_TTTGTCATCGCTGATA      1  fibrosis               1341
#
#                        log1p_n_genes_by_counts  total_counts
# SC14_AAACCTGAGCGTTCCG                 6.620073        1855.0  \
# SC14_AAACCTGAGGACATTA                 6.445720        1479.0
# SC14_AAACCTGAGTCGTTTG                 7.074117        2638.0
# SC14_AAACCTGCACATCCGG                 7.823646        9452.0
# SC14_AAACCTGCACTAGTAC                 7.038784        3883.0
# ...                                        ...           ...
# SC15_TTTGTCAGTGATGTGG                 7.040536        2724.0
# SC15_TTTGTCAGTTCGCTAA                 6.677083        2193.0
# SC15_TTTGTCATCAGTCAGT                 7.401842        4270.0
# SC15_TTTGTCATCGCGTAGC                 7.497762        7743.0
# SC15_TTTGTCATCGCTGATA                 7.201916        4184.0
#
#                        log1p_total_counts  pct_counts_in_top_20_genes
# SC14_AAACCTGAGCGTTCCG            7.526179                   25.606469  \
# SC14_AAACCTGAGGACATTA            7.299798                   26.369168
# SC14_AAACCTGAGTCGTTTG            7.878155                   20.507961
# SC14_AAACCTGCACATCCGG            9.154087                   16.314008
# SC14_AAACCTGCACTAGTAC            8.264621                   24.671646
# ...                                   ...                         ...
# SC15_TTTGTCAGTGATGTGG            7.910223                   21.145374
# SC15_TTTGTCAGTTCGCTAA            7.693481                   26.265390
# SC15_TTTGTCATCAGTCAGT            8.359603                   18.056206
# SC15_TTTGTCATCGCGTAGC            8.954674                   26.217228
# SC15_TTTGTCATCGCTGATA            8.339262                   35.229446
#
#                        total_counts_mt  log1p_total_counts_mt  pct_counts_mt
# SC14_AAACCTGAGCGTTCCG              0.0                    0.0            0.0  \
# SC14_AAACCTGAGGACATTA              0.0                    0.0            0.0
# SC14_AAACCTGAGTCGTTTG              0.0                    0.0            0.0
# SC14_AAACCTGCACATCCGG              0.0                    0.0            0.0
# SC14_AAACCTGCACTAGTAC              0.0                    0.0            0.0
# ...                                ...                    ...            ...
# SC15_TTTGTCAGTGATGTGG              0.0                    0.0            0.0
# SC15_TTTGTCAGTTCGCTAA              0.0                    0.0            0.0
# SC15_TTTGTCATCAGTCAGT              0.0                    0.0            0.0
# SC15_TTTGTCATCGCGTAGC              0.0                    0.0            0.0
# SC15_TTTGTCATCGCTGATA              0.0                    0.0            0.0
#
#                        ...  pct_counts_hb  outlier  n_counts  n_genes
# SC14_AAACCTGAGCGTTCCG  ...            0.0    False    1855.0      749  \
# SC14_AAACCTGAGGACATTA  ...            0.0    False    1479.0      629
# SC14_AAACCTGAGTCGTTTG  ...            0.0    False    2638.0     1180
# SC14_AAACCTGCACATCCGG  ...            0.0    False    9452.0     2498
# SC14_AAACCTGCACTAGTAC  ...            0.0    False    3883.0     1139
# ...                    ...            ...      ...       ...      ...
# SC15_TTTGTCAGTGATGTGG  ...            0.0    False    2724.0     1141
# SC15_TTTGTCAGTTCGCTAA  ...            0.0    False    2193.0      793
# SC15_TTTGTCATCAGTCAGT  ...            0.0    False    4270.0     1638
# SC15_TTTGTCATCGCGTAGC  ...            0.0    False    7743.0     1803
# SC15_TTTGTCATCGCTGATA  ...            0.0    False    4184.0     1341
#
#                        leiden_1  leiden_2  leiden_0_4  leiden_0_3  louvain
# SC14_AAACCTGAGCGTTCCG         3         5           4           4        4  \
# SC14_AAACCTGAGGACATTA         3         5           4           4        4
# SC14_AAACCTGAGTCGTTTG         2         4           2           2        2
# SC14_AAACCTGCACATCCGG         1         1           1           1        1
# SC14_AAACCTGCACTAGTAC         5         3           3           3        3
# ...                         ...       ...         ...         ...      ...
# SC15_TTTGTCAGTGATGTGG        12        14          10           1        5
# SC15_TTTGTCAGTTCGCTAA         5         3           3           3        3
# SC15_TTTGTCATCAGTCAGT         1         1           1           1        1
# SC15_TTTGTCATCGCGTAGC        27        33          17          15       16
# SC15_TTTGTCATCGCTGATA         0        32           0           0        0
#
#                       manual_celltype_annotation
# SC14_AAACCTGAGCGTTCCG                    B-Cells
# SC14_AAACCTGAGGACATTA                    B-Cells
# SC14_AAACCTGAGTCGTTTG       Alveolar macrophages
# SC14_AAACCTGCACATCCGG         Classical monocyte
# SC14_AAACCTGCACTAGTAC                    T-Cells
# ...                                          ...
# SC15_TTTGTCAGTGATGTGG                  Monocytes
# SC15_TTTGTCAGTTCGCTAA                    T-Cells
# SC15_TTTGTCATCAGTCAGT         Classical monocyte
# SC15_TTTGTCATCGCGTAGC             CCR7 dendridic
# SC15_TTTGTCATCGCTGATA                        AT2
#
# [15365 rows x 25 columns]

# %%
# nur spalten mit gleichem Namen werden mitgenommen
adata_peyser.obs["annotation"] = adata_peyser.obs["annotation_coarse_precise"]
adata_misharin.obs["annotation"] = adata_misharin.obs["manual_celltype_annotation"]

# %%
adata_projects = {}
# hier alle Projekte einfügen
adata_projects["Peyser"] = adata_peyser
adata_projects["Misharin"] = adata_misharin
adata = anndata.concat(adata_projects, label="projects")
adata.obs
# Out:
#                        n_genes_by_counts  log1p_n_genes_by_counts
# AAACCTGAGGAATTAC-1                  1158                 7.055313  \
# AAACCTGCATAACCTG-1                  1526                 7.331060
# AAACCTGCATTGGGCC-1                  2115                 7.657283
# AAACCTGGTCTCAACA-1                  2395                 7.781556
# AAACCTGGTTGACGTT-1                  1154                 7.051856
# ...                                  ...                      ...
# SC15_TTTGTCAGTGATGTGG               1141                 7.040536
# SC15_TTTGTCAGTTCGCTAA                793                 6.677083
# SC15_TTTGTCATCAGTCAGT               1638                 7.401842
# SC15_TTTGTCATCGCGTAGC               1803                 7.497762
# SC15_TTTGTCATCGCTGATA               1341                 7.201916
#
#                        total_counts  log1p_total_counts
# AAACCTGAGGAATTAC-1           2729.0            7.912057  \
# AAACCTGCATAACCTG-1           6030.0            8.704668
# AAACCTGCATTGGGCC-1           5689.0            8.646465
# AAACCTGGTCTCAACA-1           8031.0            8.991189
# AAACCTGGTTGACGTT-1           2060.0            7.630947
# ...                             ...                 ...
# SC15_TTTGTCAGTGATGTGG        2724.0            7.910223
# SC15_TTTGTCAGTTCGCTAA        2193.0            7.693481
# SC15_TTTGTCATCAGTCAGT        4270.0            8.359603
# SC15_TTTGTCATCGCGTAGC        7743.0            8.954674
# SC15_TTTGTCATCGCTGATA        4184.0            8.339262
#
#                        pct_counts_in_top_20_genes  total_counts_mt
# AAACCTGAGGAATTAC-1                      22.792232              0.0  \
# AAACCTGCATAACCTG-1                      23.598673              0.0
# AAACCTGCATTGGGCC-1                      19.968360              0.0
# AAACCTGGTCTCAACA-1                      28.066243              0.0
# AAACCTGGTTGACGTT-1                      18.203883              0.0
# ...                                           ...              ...
# SC15_TTTGTCAGTGATGTGG                   21.145374              0.0
# SC15_TTTGTCAGTTCGCTAA                   26.265390              0.0
# SC15_TTTGTCATCAGTCAGT                   18.056206              0.0
# SC15_TTTGTCATCGCGTAGC                   26.217228              0.0
# SC15_TTTGTCATCGCTGATA                   35.229446              0.0
#
#                        log1p_total_counts_mt  pct_counts_mt
# AAACCTGAGGAATTAC-1                       0.0            0.0  \
# AAACCTGCATAACCTG-1                       0.0            0.0
# AAACCTGCATTGGGCC-1                       0.0            0.0
# AAACCTGGTCTCAACA-1                       0.0            0.0
# AAACCTGGTTGACGTT-1                       0.0            0.0
# ...                                      ...            ...
# SC15_TTTGTCAGTGATGTGG                    0.0            0.0
# SC15_TTTGTCAGTTCGCTAA                    0.0            0.0
# SC15_TTTGTCATCAGTCAGT                    0.0            0.0
# SC15_TTTGTCATCGCGTAGC                    0.0            0.0
# SC15_TTTGTCATCGCTGATA                    0.0            0.0
#
#                        total_counts_ribo  log1p_total_counts_ribo
# AAACCTGAGGAATTAC-1                   0.0                      0.0  \
# AAACCTGCATAACCTG-1                   0.0                      0.0
# AAACCTGCATTGGGCC-1                   0.0                      0.0
# AAACCTGGTCTCAACA-1                   0.0                      0.0
# AAACCTGGTTGACGTT-1                   0.0                      0.0
# ...                                  ...                      ...
# SC15_TTTGTCAGTGATGTGG                0.0                      0.0
# SC15_TTTGTCAGTTCGCTAA                0.0                      0.0
# SC15_TTTGTCATCAGTCAGT                0.0                      0.0
# SC15_TTTGTCATCGCGTAGC                0.0                      0.0
# SC15_TTTGTCATCGCTGATA                0.0                      0.0
#
#                        pct_counts_ribo  total_counts_hb
# AAACCTGAGGAATTAC-1                 0.0              0.0  \
# AAACCTGCATAACCTG-1                 0.0              0.0
# AAACCTGCATTGGGCC-1                 0.0              0.0
# AAACCTGGTCTCAACA-1                 0.0              0.0
# AAACCTGGTTGACGTT-1                 0.0              0.0
# ...                                ...              ...
# SC15_TTTGTCAGTGATGTGG              0.0              0.0
# SC15_TTTGTCAGTTCGCTAA              0.0              0.0
# SC15_TTTGTCATCAGTCAGT              0.0              0.0
# SC15_TTTGTCATCGCGTAGC              0.0              0.0
# SC15_TTTGTCATCGCTGATA              0.0              0.0
#
#                        log1p_total_counts_hb  pct_counts_hb  outlier  n_genes
# AAACCTGAGGAATTAC-1                       0.0            0.0    False     1158  \
# AAACCTGCATAACCTG-1                       0.0            0.0    False     1526
# AAACCTGCATTGGGCC-1                       0.0            0.0    False     2115
# AAACCTGGTCTCAACA-1                       0.0            0.0    False     2395
# AAACCTGGTTGACGTT-1                       0.0            0.0    False     1154
# ...                                      ...            ...      ...      ...
# SC15_TTTGTCAGTGATGTGG                    0.0            0.0    False     1141
# SC15_TTTGTCAGTTCGCTAA                    0.0            0.0    False      793
# SC15_TTTGTCATCAGTCAGT                    0.0            0.0    False     1638
# SC15_TTTGTCATCGCGTAGC                    0.0            0.0    False     1803
# SC15_TTTGTCATCGCTGATA                    0.0            0.0    False     1341
#
#                           n_counts louvain                   annotation
# AAACCTGAGGAATTAC-1     1657.952515       0  Interstitial \n Macrophages  \
# AAACCTGCATAACCTG-1     1552.569580       5                      B-Cells
# AAACCTGCATTGGGCC-1     2086.439697       8                  Mesothelial
# AAACCTGGTCTCAACA-1     2038.384766       4        Avolare \nMacrophages
# AAACCTGGTTGACGTT-1     1799.102539       1                  Endothelial
# ...                            ...     ...                          ...
# SC15_TTTGTCAGTGATGTGG  2724.000000       5                    Monocytes
# SC15_TTTGTCAGTTCGCTAA  2193.000000       3                      T-Cells
# SC15_TTTGTCATCAGTCAGT  4270.000000       1           Classical monocyte
# SC15_TTTGTCATCGCGTAGC  7743.000000      16               CCR7 dendridic
# SC15_TTTGTCATCGCTGATA  4184.000000       0                          AT2
#
#                        projects
# AAACCTGAGGAATTAC-1       Peyser
# AAACCTGCATAACCTG-1       Peyser
# AAACCTGCATTGGGCC-1       Peyser
# AAACCTGGTCTCAACA-1       Peyser
# AAACCTGGTTGACGTT-1       Peyser
# ...                         ...
# SC15_TTTGTCAGTGATGTGG  Misharin
# SC15_TTTGTCAGTTCGCTAA  Misharin
# SC15_TTTGTCATCAGTCAGT  Misharin
# SC15_TTTGTCATCGCGTAGC  Misharin
# SC15_TTTGTCATCGCTGATA  Misharin
#
# [32909 rows x 20 columns]

# %%
sc.pp.pca(adata)
# Berechnen der Nachbarschaften
sc.pp.neighbors(adata)
# Reduzieren der Dimensionen mit UMAP
sc.tl.umap(adata)
# Out:
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
sc.pl.umap(adata=adata, color=["projects"])
# Out:
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:163: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata=adata, color=["annotation"])
# Out:
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:163: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = copy(get_cmap(cmap))
# /Users/leahollenberg/Desktop/Masterpraktikum/PycharmProjects/scanpy_start/venv/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
